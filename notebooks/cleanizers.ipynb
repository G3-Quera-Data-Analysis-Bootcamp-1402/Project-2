# %% [markdown]
# ## Prepare dimension and fact data for ML parts

# %% [markdown]
# ### Import libs

# %%
from pathlib import Path
from shutil import get_terminal_size

import pandas as pd

# %% [markdown]
# ### Define constants and useful functions

# %%
DATA_DIR = Path("../data/").resolve()
read_csv: pd.DataFrame = lambda fn, dm: pd.read_csv(DATA_DIR / f"{fn}.csv", delimiter=dm)
term_c, term_r = get_terminal_size()
sep: str = "\n" + "+-" * (term_c // 2) + "\n"
print_dfs = lambda dfs: print(*dfs, sep=sep)

# %% [markdown]
# ## Define cleanizer function for each dimension (dimensions which need preprocessing)

# %%
def customer_dim_cleanizer() -> pd.DataFrame:
    df: pd.DataFrame = pd.read_csv(DATA_DIR / "customer_dim.csv", delimiter="\t")
    df = pd.get_dummies(df, columns=["Segment"], dtype=bool)
    return df

# %%
def geo_dim_cleanizer() -> pd.DataFrame:
    df: pd.DataFrame = pd.read_csv(DATA_DIR / "geo_dim.csv", delimiter="\t")
    df = pd.get_dummies(df, columns=["Region", "Country"], dtype=bool)
    return df

# %%
def order_dim_cleanizer() -> pd.DataFrame:
    df: pd.DataFrame = pd.read_csv(DATA_DIR / "order_dim.csv", delimiter="\t")
    priorities: dict[str, int] = {
        "Low": 1,
        "Medium": 2,
        "High": 3,
        "Critical": 4
    }
    for priority_name, priority_val in priorities.items():
        df["Order Priority"] = df["Order Priority"].mask(df["Order Priority"] == priority_name, priority_val)
    df = pd.get_dummies(df, columns=["Ship Mode", "Market"], dtype=bool)    
    return df

# %%
def product_dim_cleanizer() -> pd.DataFrame:
    df: pd.DataFrame = pd.read_csv(DATA_DIR / "product_dim.csv", delimiter="\t")
    df = pd.get_dummies(df, columns=["Sub-Category","Category"], dtype=bool)
    return df

# %%
customer_df: pd.DataFrame = customer_dim_cleanizer()
geo_df: pd.DataFrame = geo_dim_cleanizer()
order_df: pd.DataFrame = order_dim_cleanizer()
product_df: pd.DataFrame = product_dim_cleanizer()
date_df: pd.DataFrame = read_csv("date_dim", "\t")
fact_df: pd.DataFrame = read_csv("fact", "\t")

dfs: list[pd.DataFrame] = [customer_df, geo_df, order_df, product_df, date_df, fact_df]

# %%
def store_cleanized_data(dfs: list[pd.DataFrame], filenames: list[str]) -> None:
    for df, fn in zip(dfs, filenames):
        df.to_csv(DATA_DIR / f"cleanized/{fn}.csv", index=False)

# %%
print_dfs(dfs)
store_cleanized_data(dfs, ["customer_dim", "geo_dim", "order_dim", "product_dim", "date_dim", "fact"])
# Out:
#      Customer ID     Customer Name  Segment_Consumer  Segment_Corporate  \
# 0       AA-10315        Alex Avila              True              False
# 1       AA-10375      Allen Armold              True              False
# 2       AA-10480      Andrew Allen              True              False
# 3       AA-10645     Anna Andreadi              True              False
# 4         AA-315        Alex Avila              True              False
# ...          ...               ...               ...                ...
# 1584    VM-21685   Valerie Mitchum             False              False
# 1585    VP-11730      Victor Preis             False              False
# 1586    VP-21730      Victor Preis             False              False
# 1587    VT-11700  Valerie Takahito             False              False
# 1588    VT-21700  Valerie Takahito             False              False
#
#       Segment_Home Office
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 1584                 True
# 1585                 True
# 1586                 True
# 1587                 True
# 1588                 True
#
# [1589 rows x 5 columns]
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
#                 Geo ID         City          State  Region_Africa  \
# 0       CA-2013-159016  Los Angeles     California          False
# 1       CA-2012-149846  Los Angeles     California          False
# 2       CA-2011-106726  Los Angeles     California          False
# 3       US-2013-116729  Los Angeles     California          False
# 4       CA-2014-133865  Los Angeles     California          False
# ...                ...          ...            ...            ...
# 25028  ES-2011-4411711        Paris  Ile-de-France          False
# 25029  ES-2013-4835750        Paris  Ile-de-France          False
# 25030  ES-2013-5668540        Paris  Ile-de-France          False
# 25031  IT-2012-2848370        Paris  Ile-de-France          False
# 25032  ES-2011-4187064        Paris  Ile-de-France          False
#
#        Region_Canada  Region_Caribbean  Region_Central  Region_Central Asia  \
# 0              False             False           False                False
# 1              False             False           False                False
# 2              False             False           False                False
# 3              False             False           False                False
# 4              False             False           False                False
# ...              ...               ...             ...                  ...
# 25028          False             False            True                False
# 25029          False             False            True                False
# 25030          False             False            True                False
# 25031          False             False            True                False
# 25032          False             False            True                False
#
#        Region_EMEA  Region_East  ...  Country_United Arab Emirates  \
# 0            False        False  ...                         False
# 1            False        False  ...                         False
# 2            False        False  ...                         False
# 3            False        False  ...                         False
# 4            False        False  ...                         False
# ...            ...          ...  ...                           ...
# 25028        False        False  ...                         False
# 25029        False        False  ...                         False
# 25030        False        False  ...                         False
# 25031        False        False  ...                         False
# 25032        False        False  ...                         False
#
#        Country_United Kingdom  Country_United States  Country_Uruguay  \
# 0                       False                   True            False
# 1                       False                   True            False
# 2                       False                   True            False
# 3                       False                   True            False
# 4                       False                   True            False
# ...                       ...                    ...              ...
# 25028                   False                  False            False
# 25029                   False                  False            False
# 25030                   False                  False            False
# 25031                   False                  False            False
# 25032                   False                  False            False
#
#        Country_Uzbekistan  Country_Venezuela  Country_Vietnam  Country_Yemen  \
# 0                   False              False            False          False
# 1                   False              False            False          False
# 2                   False              False            False          False
# 3                   False              False            False          False
# 4                   False              False            False          False
# ...                   ...                ...              ...            ...
# 25028               False              False            False          False
# 25029               False              False            False          False
# 25030               False              False            False          False
# 25031               False              False            False          False
# 25032               False              False            False          False
#
#        Country_Zambia  Country_Zimbabwe
# 0               False             False
# 1               False             False
# 2               False             False
# 3               False             False
# 4               False             False
# ...               ...               ...
# 25028           False             False
# 25029           False             False
# 25030           False             False
# 25031           False             False
# 25032           False             False
#
# [25033 rows x 163 columns]
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
#             Order ID Order Priority  Returned  Ship Mode_First Class  \
# 0      ID-2011-11126              2     False                  False
# 1      ID-2011-11385              2     False                  False
# 2      ID-2011-12596              2     False                  False
# 3      ID-2011-13114              2     False                  False
# 4      ID-2011-13170              2     False                  False
# ...              ...            ...       ...                    ...
# 25028  IN-2014-76114              3     False                  False
# 25029  IN-2014-77374              3     False                  False
# 25030  IN-2014-77934              3     False                  False
# 25031  IN-2014-81973              3     False                  False
# 25032  IN-2014-82953              3     False                  False
#
#        Ship Mode_Same Day  Ship Mode_Second Class  Ship Mode_Standard Class  \
# 0                   False                   False                      True
# 1                   False                   False                      True
# 2                   False                   False                      True
# 3                   False                   False                      True
# 4                   False                   False                      True
# ...                   ...                     ...                       ...
# 25028                True                   False                     False
# 25029                True                   False                     False
# 25030                True                   False                     False
# 25031                True                   False                     False
# 25032                True                   False                     False
#
#        Market_APAC  Market_Africa  Market_Canada  Market_EMEA  Market_EU  \
# 0             True          False          False        False      False
# 1             True          False          False        False      False
# 2             True          False          False        False      False
# 3             True          False          False        False      False
# 4             True          False          False        False      False
# ...            ...            ...            ...          ...        ...
# 25028         True          False          False        False      False
# 25029         True          False          False        False      False
# 25030         True          False          False        False      False
# 25031         True          False          False        False      False
# 25032         True          False          False        False      False
#
#        Market_LATAM  Market_US
# 0             False      False
# 1             False      False
# 2             False      False
# 3             False      False
# 4             False      False
# ...             ...        ...
# 25028         False      False
# 25029         False      False
# 25030         False      False
# 25031         False      False
# 25032         False      False
#
# [25033 rows x 14 columns]
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
#              Product ID                                       Product Name  \
# 0      OFF-EAT-10000522          Eaton Computer Printout Paper, Multicolor
# 1      OFF-EAT-10000652            Eaton Computer Printout Paper, 8.5 x 11
# 2      OFF-EAT-10000820                    Eaton Message Books, Multicolor
# 3      OFF-EAT-10000854                    Eaton Parchment Paper, Recycled
# 4      OFF-EAT-10001025                       Eaton Note Cards, Multicolor
# ...                 ...                                                ...
# 10241   FUR-TA-10004892         Chromcraft Wood Table, with Bottom Storage
# 10242   FUR-TA-10004915  Office Impressions End Table, 20-1/2"H x 24"W ...
# 10243   FUR-TA-10004937           Chromcraft Conference Table, Rectangular
# 10244   FUR-TA-10004957                  Bevis Wood Table, Fully Assembled
# 10245   FUR-TA-10004972                 Chromcraft Wood Table, Rectangular
#
#        Sub-Category_Accessories  Sub-Category_Appliances  Sub-Category_Art  \
# 0                         False                    False             False
# 1                         False                    False             False
# 2                         False                    False             False
# 3                         False                    False             False
# 4                         False                    False             False
# ...                         ...                      ...               ...
# 10241                     False                    False             False
# 10242                     False                    False             False
# 10243                     False                    False             False
# 10244                     False                    False             False
# 10245                     False                    False             False
#
#        Sub-Category_Binders  Sub-Category_Bookcases  Sub-Category_Chairs  \
# 0                     False                   False                False
# 1                     False                   False                False
# 2                     False                   False                False
# 3                     False                   False                False
# 4                     False                   False                False
# ...                     ...                     ...                  ...
# 10241                 False                   False                False
# 10242                 False                   False                False
# 10243                 False                   False                False
# 10244                 False                   False                False
# 10245                 False                   False                False
#
#        Sub-Category_Copiers  Sub-Category_Envelopes  ...  Sub-Category_Labels  \
# 0                     False                   False  ...                False
# 1                     False                   False  ...                False
# 2                     False                   False  ...                False
# 3                     False                   False  ...                False
# 4                     False                   False  ...                False
# ...                     ...                     ...  ...                  ...
# 10241                 False                   False  ...                False
# 10242                 False                   False  ...                False
# 10243                 False                   False  ...                False
# 10244                 False                   False  ...                False
# 10245                 False                   False  ...                False
#
#        Sub-Category_Machines  Sub-Category_Paper  Sub-Category_Phones  \
# 0                      False                True                False
# 1                      False                True                False
# 2                      False                True                False
# 3                      False                True                False
# 4                      False                True                False
# ...                      ...                 ...                  ...
# 10241                  False               False                False
# 10242                  False               False                False
# 10243                  False               False                False
# 10244                  False               False                False
# 10245                  False               False                False
#
#        Sub-Category_Storage  Sub-Category_Supplies  Sub-Category_Tables  \
# 0                     False                  False                False
# 1                     False                  False                False
# 2                     False                  False                False
# 3                     False                  False                False
# 4                     False                  False                False
# ...                     ...                    ...                  ...
# 10241                 False                  False                 True
# 10242                 False                  False                 True
# 10243                 False                  False                 True
# 10244                 False                  False                 True
# 10245                 False                  False                 True
#
#        Category_Furniture  Category_Office Supplies  Category_Technology
# 0                   False                      True                False
# 1                   False                      True                False
# 2                   False                      True                False
# 3                   False                      True                False
# 4                   False                      True                False
# ...                   ...                       ...                  ...
# 10241                True                     False                False
# 10242                True                     False                False
# 10243                True                     False                False
# 10244                True                     False                False
# 10245                True                     False                False
#
# [10246 rows x 22 columns]
# +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-
